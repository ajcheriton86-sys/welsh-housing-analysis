# %%
import pandas as pd

# %%
df = pd.read_csv("HOUS0413.csv")

# %%
df.head()
# Out:
#    Data values  Data values_sort Data description  Data description_reference  \
# 0        207.0             207.0   All households                          10
# 1       2568.0            2568.0   All households                          10
# 2       3645.0            3645.0   All households                          10
# 3       2118.0            2118.0   All households                          10
# 4        942.0             942.0   All households                          10
#
#    Data description_sort  Data description_hierarchy                   Period  \
# 0                      1                         NaN  2025-26 April-September
# 1                      1                         NaN  2025-26 April-September
# 2                      1                         NaN  2025-26 April-September
# 3                      1                         NaN  2025-26 April-September
# 4                      1                         NaN  2025-26 April-September
#
# ...

# %%
df.shape
# Out:
# (45774, 19)

# %%
df.columns
# Out:
# Index(['Data values', 'Data values_sort', 'Data description',
#        'Data description_reference', 'Data description_sort',
#        'Data description_hierarchy', 'Period', 'Period_reference',
#        'Period_sort', 'Period_hierarchy', 'Area', 'Area_reference',
#        'Area_sort', 'Area_hierarchy', 'Outcomes', 'Outcomes_reference',
#        'Outcomes_sort', 'Outcomes_hierarchy', 'Notes'],
#       dtype='str')

# %%
df['Area'].unique()
# Out:
# <StringArray>
# [                   'Wales',              'North Wales',
#  'Mid and South West Wales',         'South East Wales',
#          'Isle of Anglesey',                  'Gwynedd',
#                     'Conwy',             'Denbighshire',
#                'Flintshire',                  'Wrexham',
#                     'Powys',               'Ceredigion',
#             'Pembrokeshire',          'Carmarthenshire',
#                   'Swansea',        'Neath Port Talbot',
#                  'Bridgend',        'Vale of Glamorgan',
#                   'Cardiff',        'Rhondda Cynon Taf',
#            'Merthyr Tydfil',               'Caerphilly',
#             'Blaenau Gwent',                  'Torfaen',
#             'Monmouthshire',                  'Newport']
# Length: 26, dtype: str

# %%
df['Period'].unique()
# Out:
# <StringArray>
# [ '2025-26 April-September',           '2024-25 Annual',
#   '2024-25 April-September',           '2023-24 Annual',
#   '2023-24 April-September',           '2022-23 Annual',
#            '2021-22 Annual',           '2020-21 Annual',
#            '2019-20 Annual',       '2019-20 April-June',
#    '2019-20 July-September', '2019-20 October-December',
#     '2019-20 January-March',           '2018-19 Annual',
#        '2018-19 April-June',   '2018-19 July-September',
#  '2018-19 October-December',    '2018-19 January-March',
#            '2017-18 Annual',       '2017-18 April-June',
#    '2017-18 July-September', '2017-18 October-December',
#     '2017-18 January-March',           '2016-17 Annual',
#        '2016-17 April-June',   '2016-17 July-September',
#  '2016-17 October-December',    '2016-17 January-March',
#            '2015-16 Annual',       '2015-16 April-June',
#    '2015-16 July-September', '2015-16 October-December',
#     '2015-16 January-March']
# ...

# %%
df['Outcomes'].unique()
# Out:
# <StringArray>
# [                                                                                                              'Ineligible households',
#                                                                           'Eligible, but not homeless or threatened with homelessness',
#                             'Number of outcomes - Eligible, threatened with homelessness, prevention assistance provided (Section 66)',
#                          'Successful prevention - Eligible, threatened with homelessness, prevention assistance provided (Section 66)',
#                        'Unsuccessful prevention - Eligible, threatened with homelessness, prevention assistance provided (Section 66)',
#                             'Assistance Refused - Eligible, threatened with homelessness, prevention assistance provided (Section 66)',
#                               'Non co-operation - Eligible, threatened with homelessness, prevention assistance provided (Section 66)',
# ...
